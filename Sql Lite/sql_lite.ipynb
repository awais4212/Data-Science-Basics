# %% [markdown]
# #### SQL Lite

# %% [markdown]
# >SQLite is a lightweight database system that stores all data in a single file and uses SQL commands.

# %%
import sqlite3

# %%
conn = sqlite3.connect('example.db')
conn

# %%
cursor = conn.cursor()

# %% [markdown]
# #### Create Query

# %%
#### create a table 
cursor.execute('''
Create Table If Not Exists employees(
ID INTEGER Primary Key,
Name TEXT Not Null,
Age INTEGER,
Department Text Not Null
)          
''')

### commit the changes 
conn.commit()

# %%
#### Insert the Values into the Tables
cursor.execute('''
    Insert into employees(Name,Age, Department)
                values('Awais',22, 'Data Scientist')
''')

cursor.execute('''
    Insert into employees(Name,Age, Department)
                values('Mohid',25, 'Hacker')
''')

cursor.execute('''
    Insert into employees(Name,Age, Department)
                values('lakho',22, 'Networker')
''')

## Commit 
conn.commit()

# %% [markdown]
# #### Read Query

# %%
## Select the particular data from the dataset
cursor.execute('''
    Select * From employees
''')

## use fetchall function 
rows = cursor.fetchall()

## print using the FOR loop 
for row in rows:
    print(row)

# %%
## reading the data from DB using the Pandas
import pandas as pd
df = pd.read_sql_query("select * from employees", conn)
df

# %% [markdown]
# #### Update Query

# %%
cursor.execute('''
Update employees
Set Age = 21
where Name = "Awais"
''')

# %% [markdown]
# #### Drop | Delete Query
# > Delete used to remove a record
# > Whereas, Drop use delete or remove the complete table|

# %%
### Drop the Table from the DataBase Query 
cursor.execute('''
DROP TABLE IF EXISTS employees
''')
conn.commit()

# %%
### Delete The Record From the Database
cursor.execute('''
delete From employees
where name = "Mohid"
''')

conn.commit()

# %% [markdown]
# #### SQL Project

# %%
conn = sqlite3.connect("Sales.db")
cursor = conn.cursor()

# %%
cursor.execute('''
Create Table if not exists sales(
    Product_ID Integer Primary Key,
    Date Text Not NULL,
    Product Text Not Null,
    Sales Integer,
    Region Text Not Null
)               
''')

sales_data = [
    ('12-2-2023','Bottle', 100, 'Karachi'),
    ('31-7-2025','Spray', 100, 'Karachi'),
    ('11-9-2023','keyboard', 100, 'Karachi'),
    ('1-5-2020','LCD', 100, 'Karachi'),
    ('29-2-2026','Light', 200, 'Islamabad')
]
conn.commit()

# %%
cursor.executemany('''
insert into sales(Date, Product, Sales, Region)
    values(?,?,?,?)
''',sales_data)
conn.commit()

# %%
cursor.execute('''
    select * From sales
''')

rows = cursor.fetchall()
for row in rows:
    print(row)
conn.commit()

# %% [markdown]
# #### Assignments

# %%
### Assignment 1: Creating and Connecting to a Database

#1. Write a Python function to create a new SQLite3 database named `test.db`.
def createDB():
    conn = sqlite3.connect('test.db')
    conn.close()
    print("Database Connected Succesfully")

createDB()

# %%
#2. Write a Python function to create a table named `employees` with columns `id` (integer), `name` (text), `age` (integer), and `department` (text) in the `test.db` database.
def createTable():
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()
    cursor.execute('''
        Create Table If Not Exists employees(
            ID Integer Primary Key,
            Name Text Not Null,
            Age Integer,
            Department Text Not Null
        )
    ''')
    conn.commit()
    conn.close()
    print('Table has been Created Successfully')
    
createTable()

# %%
### Assignment 2: Inserting Data


# 1. Write a Python function to insert a new employee into the `employees` table.
def insertDB(id, name, age, dept):
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()
    cursor.execute(
        """
            Insert Into employees(ID, Name, Age, Department)
                values(?,?,?,?)        
    """,(id, name, age, dept),
    )
    conn.commit()
    conn.close
    print("Inserted Successfully")

insertDB(1,'Awais', 22, 'CS')

# %%
# 2. Insert at least 5 different employees into the `employees` table.
insertDB(2,'Mohid',25,'Cyber')
insertDB(3,'Momina',22,'Networking')
insertDB(4,'Ronaldo',41,'Football')
insertDB(5,'Goku',28,'Fighter')
insertDB(6,'Lakho',22,'Derma')

# %%
def fetch_all_employees():
    conn = sqlite3.connect("test1.db")
    cursor = conn.cursor()
    cursor.execute('''
     Select * From employees            
    ''', ())
    rows = cursor.fetchall()
    conn.close()
    for row in rows:
        print(row)

# %%
fetch_all_employees()

# %%
def fetch_all_employees_by_Name(Name):
    conn = sqlite3.connect("test.db")
    cursor = conn.cursor()
    cursor.execute('''
     Select * From employees  Where Name = ?            
    ''', (Name,))
    rows = cursor.fetchall()
    conn.close()
    for row in rows:
        print(row)

# %%
fetch_all_employees_by_Name('Awais')

# %% [markdown]
# ### Assignment 4: Updating Data
#
# 1. Write a Python function to update the department of an employee based on their `id`.

# %%
def updateData(id,dept):
        conn = sqlite3.connect('test.db')
        cursor = conn.cursor()
        cursor.execute('''
        Update employees
        set Department = ?
        where ID = ?
    ''', (dept, id))
        conn.commit()
        conn.close()
        print("Updated Successfully")

# %%
updateData(1,'Data Science')

# %% [markdown]
# ### Assignment 5: Deleting Data
#
# 1. Write a Python function to delete an employee from the `employees` table based on their `id`.

# %%
def deleteData(id):
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()
    cursor.execute('''
         Delete From employees
         where ID = ?         
    ''',(id,))
    conn.commit()
    conn.close()
    print('Record Deleted Successfully')

# %% [markdown]
# 2. Delete at least 1 employee and display the remaining records.

# %%
deleteData(2)

fetch_all_employees()

# %% [markdown]
# ### Assignment 6: Advanced Queries
#
# 1. Write a Python function to fetch and display employees older than a certain age.

# %%
def fetchbyAge(age):
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()
    cursor.execute('''
    select * From employees
    where Age > ?
    ''',(age,))
    rows = cursor.fetchall()
    for row in rows:
        print(row)
    conn.commit()
    conn.close()
    
fetchbyAge(22)

# %% [markdown]
# 2. Write a Python function to fetch and display employees whose names start with a specific letter.

# %%
def findbyLetter(letter):
    conn = sqlite3.connect('test1.db')
    cursor = conn.cursor()
    cursor.execute('''
            Select * from employees
            where Name like ?     
    ''', (letter + '%',))
    row = cursor.fetchall()
    for rows in row:
        print(rows)
    conn.commit()
    conn.close()

findbyLetter('A')

# %% [markdown]
# ### Assignment 7: Handling Transactions
#
# 1. Write a Python function to insert multiple employees into the `employees` table in a single transaction. Ensure that if any insertion fails, none of the insertions are committed.

# %%
def manyInstertion(emp):
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()
    try:
        cursor.executemany('''
                    Insert INTO employees(ID,Name,Age,Department)
                        values(?,?,?,?)
        ''',emp)
        conn.commit()
        print('All Empoloyees Records Inserted Succesfully')
    except Exception as e:
        conn.rollback()
        print("An error Occured: ")
        print(e)
    finally:
        conn.close()
            
employees1 = [
    (7,'Haider', 28, 'IT'),
    (8,'Karrar', 35, 'AI'),
    (9,'Meesum', 22, 'Data Science'),
    (10,'Muhammad', 22, 'Cyber Security')
]

manyInstertion(employees1)

# %%
def displayRecords():
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()
    cursor.execute("Select * From employees")
    try:
        records = cursor.fetchall()
        for row in records:
            print(row)
    except Exception as e:
        print('An Error Occured Due to This:')
        print(e) 
        
displayRecords()
# Out:
# (1, 'Awais', 23, 'Data Science', None)
# (3, 'Momina', 23, 'Networking', None)
# (4, 'Ronaldo', 42, 'Football', None)
# (5, 'Goku', 28, 'Fighter', None)
# (6, 'Lakho', 25, 'Derma', None)
# (7, 'Haider', 28, 'IT', None)
# (8, 'Karrar', 35, 'AI', None)
# (9, 'Meesum', 22, 'Data Science', None)
# (10, 'Muhammad', 22, 'Cyber Security', None)

# %%
def updateAge(updatedAge):
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()
    try:
        cursor.executemany('''
                Update Employees
                set Age = ?
                where ID = ?                    
        ''', updatedAge)
        conn.commit()
        print("Age Updated Successfully")
    except Exception as e:
        conn.rollback()
        print('An Error Occured:')
        print(e)
    finally:
        conn.close()

updatedAge = [
    (23,1),
    (23,3),
    (23,2),
    (42,4),
    (25,6)
]

updateAge(updatedAge)

# %%
def displayRecords():
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()
    cursor.execute("Select * From employees")
    try:
        records = cursor.fetchall()
        for row in records:
            print(row)
    except Exception as e:
        print('An Error Occured Due to This:')
        print(e) 
        
displayRecords()

# %% [markdown]
# ### Assignment 8: Creating Relationships
#
# 1. Create a new table named `departments` with columns `id` (integer) and `name` (text).

# %%
def createDepartmentTable():
    conn = sqlite3.connect("test.db")
    cursor = conn.cursor()
    cursor.execute("""
            Create Table IF Not Exists Department(
                ID Integer Primary Key,
                Name Text not null  
            )
    """)
    conn.commit()
    conn.close()
    print('Department Table has been Created')

createDepartmentTable()

# %% [markdown]
# 2. Modify the `employees` table to include a foreign key referencing the `id` column in the `departments` table.

# %%
import sqlite3

# %%
def departmentForeignKey():
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()
    cursor.executescript('''
            PRAGMA foreign_keys=off;
            BEGIN TRANSACTION;
            Alter Table employees RENAME TO oldEmployees;
            create Table employees(
                ID Integer,
                Name TEXT NOT NULL,
                Age INTEGER,
                Department TEXT NOT NULL,
                DepartmentID Integer,
                Foreign Key(DepartmentID) REFERENCES Department(ID)
            );
            Insert INTO employees (ID,Name,Age,Department)
            select ID,Name,Age,Department From oldEmployees;
            Drop Table oldEmployees;
            COMMIT;
            Pragma Foreign_Keys=on;                    
    ''')
    conn.commit()
    conn.close()
    print('"employees" Table Modified successfully')

departmentForeignKey()
# Out:
# "employees" Table Modified successfully

# %% [markdown]
# 3. Write a Python function to insert data into both the `departments` and `employees` tables, ensuring referential integrity.

# %%
def insert_department_and_employee(dID, dName, eID, eName, eAge , department):
    conn = sqlite3.connect('test.db')
    cursor = conn.cursor()
    try:
        cursor.execute('''
                        Insert Into Department(ID, Name)
                        values(?,?)
        ''',(dID,dName))
        cursor.execute('''
                    Insert Into employees(ID, Name, Age, Department,DepartmentID)
                            Values(?,?,?,?,?)
                            
        ''',(eID,eName,eAge,department, dID))
        conn.commit()
        print('Inserted Data Successfully')
    except Exception as e:
        conn.rollback()
        print('An Error Occurred due to this')
        print(e)
    finally:
        conn.close()
    

insert_department_and_employee(11,'Data Science', 11, 'Fareed', 23, 'Data Science')
# Out:
# Inserted Data Successfully

# %%
conn = sqlite3.connect('test.db')
cursor = conn.cursor()
cursor.execute("Select * From Employees")
conn.close
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, 'Awais', 23, 'Data Science', None)
# (3, 'Momina', 23, 'Networking', None)
# (4, 'Ronaldo', 42, 'Football', None)
# (5, 'Goku', 28, 'Fighter', None)
# (6, 'Lakho', 25, 'Derma', None)
# (7, 'Haider', 28, 'IT', None)
# (8, 'Karrar', 35, 'AI', None)
# (9, 'Meesum', 22, 'Data Science', None)
# (10, 'Muhammad', 22, 'Cyber Security', None)
# (11, 'Fareed', 23, 'Data Science', 11)

# %%
import pandas as pd

conn = sqlite3.connect('test.db')
cursor = conn.cursor()

eDF = pd.read_sql_query('''Select * from employees''', conn)
dDF = pd.read_sql_query('''Select * from Department''',conn)
conn.close()

merge = pd.merge(eDF,dDF,left_on='DepartmentID',right_on='ID', how='left')
merge
# Out:
#    ID_x    Name_x  Age      Department  DepartmentID  ID_y        Name_y
# 0     1     Awais   23    Data Science           NaN   NaN           NaN
# 1     3    Momina   23      Networking           NaN   NaN           NaN
# 2     4   Ronaldo   42        Football           NaN   NaN           NaN
# 3     5      Goku   28         Fighter           NaN   NaN           NaN
# 4     6     Lakho   25           Derma           NaN   NaN           NaN
# 5     7    Haider   28              IT           NaN   NaN           NaN
# 6     8    Karrar   35              AI           NaN   NaN           NaN
# 7     9    Meesum   22    Data Science           NaN   NaN           NaN
# 8    10  Muhammad   22  Cyber Security           NaN   NaN           NaN
# 9    11    Fareed   23    Data Science          11.0  11.0  Data Science
